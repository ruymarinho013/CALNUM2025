# %% [markdown]
# <a href="https://colab.research.google.com/github/ruymarinho013/CALNUM2025/blob/main/SistemasR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

def gauss_jordan(A, b):
  #combina a matriz dos coeficientes A com os termos independentes b
  n = len(b)
  Ab = np.hstack([A.astype(float),b.reshape(-1,1).astype(float)])

  #Eliminação de Gauss-Jordan
  for i in range(n):
    #pivó principal
    pivo = Ab[i,i]
    if pivo ==0:
      raise ValueError("Pivo nulo! sistemas pode não ter solução única")
      #normalização da linha do pivó
      Ab[i] = Ab[i]/pivo

    #zerar os outros elementos da coluna i
    for j in range(n):
      if j != i:
        fator = Ab[j, i]
        Ab[j] = Ab[j] - fator*Ab[i]
  X = Ab[:, -1]
  return X

# %%
#Exemplo

A = np.array([[2,-1,1],
              [3,3,9],
              [3,3,5]], dtype=float)
b = np.array([8,0,-6], dtype=float)

solucao = gauss_jordan(A,b)
print("Solução do sistema;")
for i, val in enumerate(solucao, start=1):
  print(f"x{i} = {val:.4f}")
# Out:
# Solução do sistema;
# x1 = -814.0000
# x2 = -708.0000
# x3 = 114.0000
